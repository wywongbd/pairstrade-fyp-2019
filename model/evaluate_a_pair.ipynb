# %%
cd ~/fyp/code/
# Out:
# /home/u21376/fyp/code

# %%
import sys

sys.path.append('./log_helper')
sys.path.append('./model')

# %%
from rl_train import run_rl_backtest
# Some more magic so that the notebook will reload external python modules;
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
df1, df2 = run_rl_backtest('AER', 'AAN', 3)
# df1, df2 = run_rl_backtest('NEWR', 'TYL', 3)
# Out:
# 2019-04-16 15:25:23,132 INFO - log_helper - Finished configuring logger
# 2019-04-16 15:25:23,133 INFO - rl_train - Hello World!
# 2019-04-16 15:25:23,134 INFO - rl_train - Namespace(batch_size=300, batches_per_print=50, gamma=0.0005, h_dim=150, job_name='0412_train_012_test_3', layer1_out_num=50, load_which_data='tech', lr=0.0005, num_of_epoch=80, num_rnn_layers=1, rand_action_prob=0.0, reg=1e-05, run_mode='plot_distribution', test_indices=[1], train_indices=[0])
# 2019-04-16 15:25:23,135 INFO - rl_train - config.train_indices = [0]
# 2019-04-16 15:25:23,136 INFO - rl_train - config.test_indices = [1]
# 2019-04-16 15:25:23,136 INFO - rl_train - num_of_batch = 3557
# 2019-04-16 15:25:23,137 INFO - rl_load_data - raw csv files loaded from ./model/dataset/nyse-daily-trimmed-same-length/*.csv
# 2019-04-16 15:25:23,326 INFO - rl_load_data - Total number of pair slices: 26680
# 2019-04-16 15:25:23,339 INFO - rl_load_data - Total number of pair slices for period 0: 1
# 2019-04-16 15:25:23,340 INFO - rl_load_data - Total number of pair slices for period 1: 1
# 2019-04-16 15:25:23,341 INFO - rl_load_data - Total number of pair slices for period 2: 1
# 2019-04-16 15:25:23,342 INFO - rl_load_data - Total number of pair slices for period 3: 1
# 2019-04-16 15:25:23,357 INFO - rl_load_data - time spent for loading df = 0.014766931533813477s
# 2019-04-16 15:25:23,358 INFO - rl_load_data - trading_period is 200
# 2019-04-16 15:25:23,362 INFO - rl_train - restore model from ./model/logging/0412_train_012_test_3/saved_models/20190413_024746
# 2019-04-16 15:25:23,363 INFO - rl_train - evaluate return distribution
# 2019-04-16 15:25:23,391 INFO - trading_env - name AER-AAN-3
# 2019-04-16 15:25:23,393 INFO - trading_env - name1 AAN-AER-3
# 2019-04-16 15:25:23,394 INFO - trading_env - keys ['AAN-AER-0', 'AAN-AER-1', 'AAN-AER-2', 'AAN-AER-3']
# 2019-04-16 15:25:23,431 INFO - rl_train - this batch size should be 1: 1
