# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

# %%
def max_returns_per_lookback(summary):
    # returns the chart of the max returns given summary.csv
    summary_max = summary.groupby('lookback')['avg_overall_return'].max()

    X = summary_max.index
    Y = summary_max

    plt.plot(X,Y)
    plt.show()
    
def generate_mktcap_size(mkt_cap_info):
    
    # adds new column 'Size' based on market cap
    
    # mkt cap definition, link: https://www.nasdaq.com/article/market-cap-explained-cm954078
    # Mega-cap: Market value of $300 billion or more;
    # Large-cap: Market value between $10 billion and $300 billion;
    # Mid-cap: Market value between $2 billion and $10 billion;
    # Small-cap: Market value between $250 million and $2 billion;
    # Micro-cap: Market value of less than $250 million.

    mkt_cap_info['Size'] = 'Mega'
    mkt_cap_info.loc[mkt_cap_info['MarketCap'].between(0, 250000000, inclusive=False), 'Size'] = 'Micro'
    mkt_cap_info.loc[mkt_cap_info['MarketCap'].between(250000000, 2000000000, inclusive=False), 'Size'] = 'Small'
    mkt_cap_info.loc[mkt_cap_info['MarketCap'].between(2000000000, 10000000000, inclusive=False), 'Size'] = 'Mid'
    mkt_cap_info.loc[mkt_cap_info['MarketCap'].between(10000000000, 300000000000, inclusive=False), 'Size'] = 'Large'

    return mkt_cap_info

    
def get_pair_type(pair_data, mkt_cap_info):
    # given pair data and separate mkt_cap_info, this will return the SIZE-SIZE pairing as a new column
    pair_type = []
    for i in range(0,len(pair_data)):
        pair = [str(mkt_cap_info.loc[mkt_cap_info['Symbol'] == pair_data.pair.str.split("-")[i][0], "Size"].values[0]), str(mkt_cap_info.loc[mkt_cap_info['Symbol'] == pair_data.pair.str.split("-")[i][1], "Size"].values[0])]
        pair.sort()
        pair_type.append('-'.join(pair))

    pair_data['pair_type'] = pd.Series(pair_type) 

    return pair_data.groupby(['pair_type']).mean().sort_values(by = 'sharpe_ratio', ascending = False)

# %%
summary = pd.read_csv(filepath_or_buffer = "~/Desktop/summary.csv")
# summary = original_file[['lookback', 'enter_threshold_size', 'exit_threshold_size', 'loss_limit', 'avg_sharpe_ratio', 'avg_overall_return', 'overall_return_std']]

idx_lookback = summary.groupby(['lookback'])['avg_overall_return'].transform(max) == summary['avg_overall_return']
idx_enter_threshold = summary.groupby(['enter_threshold_size'])['avg_overall_return'].transform(max) == summary['avg_overall_return'] 
idx_exit_threshold = summary.groupby(['exit_threshold_size'])['avg_overall_return'].transform(max) == summary['avg_overall_return'] 
idx_loss_limit = summary.groupby(['loss_limit'])['avg_overall_return'].transform(max) == summary['avg_overall_return'] 


summary['avg_overall_return'] = round(summary['avg_overall_return'],4)*100
best_params = pd.concat([summary[idx_lookback], summary[idx_enter_threshold], summary[idx_exit_threshold], summary[idx_loss_limit]], join = 'inner')

# get the pair size info
nyse_info = pd.read_csv(filepath_or_buffer = "~/Desktop/FYP/statistical-arbitrage-private-18-19/stock-names/nyse_tech_list.csv")
mkt_cap_info = generate_mktcap_size(nyse_info[['Symbol', 'MarketCap']])
# Out:
# /Users/brendantham/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/brendantham/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
# summary parameters file by max overall returns
best_params.sort_values(by = 'avg_sharpe_ratio', ascending = False)[['lookback', 'enter_threshold_size', 'exit_threshold_size', 'loss_limit', 'avg_sharpe_ratio', 'avg_overall_return', 'overall_return_std']].drop_duplicates()
# Out:
#      lookback  enter_threshold_size  exit_threshold_size  loss_limit  \
# 82         25                   2.0                 0.50      -0.010
# 111        30                   2.0                 0.75      -0.005
# 28         15                   2.0                 0.50      -0.010
# 21         10                   3.0                 0.75      -0.005
# 26         10                   3.0                 1.00      -0.020
# 15         10                   2.5                 1.00      -0.005
# 54         20                   2.0                 0.50      -0.005
#
#      avg_sharpe_ratio  avg_overall_return  overall_return_std
# 82           0.668280               24.93            0.453489
# 111          0.462560               23.00            0.485430
# 28           0.261036               16.95            0.432920
# 21           0.249398               19.50            0.443372
# 26           0.187420               15.96            0.450370
# 15           0.105822               21.30            0.582905
# 54          -0.029786               16.03            0.421483

# %%
best_params.sort_values(by = 'avg_sharpe_ratio', ascending = False)
# Out:
#      lookback  enter_threshold_size  exit_threshold_size  loss_limit  \
# 82         25                   2.0                 0.50      -0.010
# 82         25                   2.0                 0.50      -0.010
# 82         25                   2.0                 0.50      -0.010
# 82         25                   2.0                 0.50      -0.010
# 111        30                   2.0                 0.75      -0.005
# 111        30                   2.0                 0.75      -0.005
# 111        30                   2.0                 0.75      -0.005
# 28         15                   2.0                 0.50      -0.010
# 21         10                   3.0                 0.75      -0.005
# 26         10                   3.0                 1.00      -0.020
# 15         10                   2.5                 1.00      -0.005
# 15         10                   2.5                 1.00      -0.005
# 15         10                   2.5                 1.00      -0.005
# 54         20                   2.0                 0.50      -0.005
#
#      avg_sharpe_ratio  avg_overall_return  overall_return_std  \
# 82           0.668280               24.93            0.453489
# 82           0.668280               24.93            0.453489
# 82           0.668280               24.93            0.453489
# 82           0.668280               24.93            0.453489
# 111          0.462560               23.00            0.485430
# 111          0.462560               23.00            0.485430
# 111          0.462560               23.00            0.485430
# 28           0.261036               16.95            0.432920
# 21           0.249398               19.50            0.443372
# 26           0.187420               15.96            0.450370
# 15           0.105822               21.30            0.582905
# 15           0.105822               21.30            0.582905
# 15           0.105822               21.30            0.582905
# 54          -0.029786               16.03            0.421483
#
#                                      uuid
# 82   111434e3-d064-4989-ab85-d759b026671c
# 82   111434e3-d064-4989-ab85-d759b026671c
# 82   111434e3-d064-4989-ab85-d759b026671c
# 82   111434e3-d064-4989-ab85-d759b026671c
# 111  2c6e9a61-0707-4e64-9bd6-0e59f34ec2ee
# 111  2c6e9a61-0707-4e64-9bd6-0e59f34ec2ee
# 111  2c6e9a61-0707-4e64-9bd6-0e59f34ec2ee
# 28   c8e80eda-b75e-46d6-9af9-2e5fea082f04
# 21   a22c72b9-c6e0-45d2-b321-612408997b29
# 26   1326137a-9a9a-4b63-9d3b-380818102f06
# 15   97ccf78c-1073-4db4-a36a-10f7c789f10f
# 15   97ccf78c-1073-4db4-a36a-10f7c789f10f
# 15   97ccf78c-1073-4db4-a36a-10f7c789f10f
# 54   89651f4b-6c52-4c8c-8f68-8279c63de971

# %%
pair_data_good =  pd.read_csv(filepath_or_buffer = "~/Downloads/nyse-tech-daily/111434e3-d064-4989-ab85-d759b026671c.csv")
pair_data_good['returns_std_thousands'] = round(pair_data_good['returns_std']/1000,3)
get_pair_type(pair_data_good[['pair', 'sharpe_ratio', 'overall_return', 'returns_std_thousands']])
# Out:
#              sharpe_ratio  overall_return  returns_std_thousands
# pair_type
# Large-Small      1.834386        0.187991              21.110333
# Micro-Small      1.240984        0.431717              37.005500
# Large-Mid        1.071801        0.225274              16.985813
# Mid-Mid          0.643682        0.226737              15.375133
# Small-Small      0.297450        0.152565              24.614333
# Mid-Small        0.059445        0.503374              33.510200
# Micro-Mid       -0.137801       -0.408978              36.046000
# Large-Large     -1.686917       -0.465395              12.768000

# %%
pair_data_med =  pd.read_csv(filepath_or_buffer = "~/Downloads/nyse-tech-daily/c8e80eda-b75e-46d6-9af9-2e5fea082f04.csv")
pair_data_med['returns_std_thousands'] = round(pair_data_med['returns_std']/1000,3)
get_pair_type(pair_data_med[['pair', 'sharpe_ratio', 'overall_return', 'returns_std_thousands']])
# Out:
#              sharpe_ratio  overall_return  returns_std_thousands
# pair_type
# Micro-Small      3.340162        0.604635              37.488500
# Small-Small      1.115527        0.339393              29.907667
# Large-Small      0.489912        0.299772              23.410333
# Large-Mid        0.433038        0.186416              17.538875
# Mid-Mid          0.053358        0.113611              15.673067
# Micro-Mid       -0.059213       -0.184780              57.568000
# Mid-Small       -0.089825        0.253314              26.907500
# Large-Large     -1.840137       -0.680303              14.444000

# %%
pair_data_bad =  pd.read_csv(filepath_or_buffer = "~/Downloads/nyse-tech-daily/89651f4b-6c52-4c8c-8f68-8279c63de971.csv")
pair_data_bad['returns_std_thousands'] = round(pair_data_bad['returns_std']/1000,3)
get_pair_type(pair_data_bad[['pair', 'sharpe_ratio', 'overall_return', 'returns_std_thousands']])
# Out:
#              sharpe_ratio  overall_return  returns_std_thousands
# pair_type
# Micro-Small      2.542863        0.506554              36.629000
# Large-Small      0.645571        0.403501              24.034667
# Small-Small      0.221369        0.015718              27.134000
# Mid-Mid          0.121766        0.108520              14.773467
# Mid-Small        0.034851        0.283354              29.210200
# Micro-Mid       -0.265830       -0.289394              39.508000
# Large-Mid       -0.738331        0.185205              17.088000
# Large-Large     -1.574767       -0.452823              13.128000

# %%
pair_data_good.sort_values(by = "overall_return", ascending = False)
# Out:
#          pair  sharpe_ratio  overall_return   returns_std  \
# 62   LXFT-NSP      0.690549        1.506739  67640.299696
# 19  EPAM-LXFT      0.728523        1.446005  60031.723921
# 12  HUBS-LXFT      0.638973        1.387230  75049.281682
# 4     NSP-STM      2.017444        1.067776  30168.690649
# 55  LXFT-MODN      1.596089        1.055199  21077.648227
# 5    AER-ELLI      1.252058        0.820399  27160.144729
# 63   ASGN-NOW      1.015616        0.774435  25536.205466
# 56  EPAM-PANW     16.926862        0.753443  22144.078603
# 47    FDS-MAN      1.313628        0.701424  14560.599446
# 42  LXFT-PANW      5.785681        0.689805  24615.012651
# 2     AER-NSP      2.206887        0.594352  20297.100729
# 11   ASGN-FDS      1.239818        0.588079  16930.451230
# 15  ELLI-PANW      2.041945        0.548311  25638.452872
# 24   FDS-PAYC      3.285401        0.542964  17898.970334
# 31   FDS-GWRE      1.582981        0.542392  14351.162366
# 21   ELLI-STM      0.580689        0.536370  16261.289462
# 0     FDS-NOW      1.009004        0.510699  17337.217244
# 34   LXFT-MAN      0.739534        0.506193  21695.155600
# 13  ELLI-LXFT      0.580632        0.471219  34982.075556
# 50   IPG-LXFT      0.496783        0.457926  17542.544388
# 58    SPA-UIS      1.268205        0.451125  27153.404763
# 8    AER-ASGN      3.423129        0.431641  18825.069067
# 17  LXFT-SQNS      1.213762        0.412308  46858.451297
# 39  ELLI-HUBS      1.401195        0.409738  20083.063977
# 52   ASGN-MAN      0.873278        0.354106  12654.456205
# 18   ASGN-STM      0.927735        0.352908  11466.367962
# 6     AL-ASGN      0.722942        0.315959  13536.891353
# 14   ELLI-NSP      0.553976        0.292905  17934.757365
# 61    ITW-TYL      0.369326        0.268446  13606.482752
# 20   ELLI-FDS      1.970918        0.223887  20083.778618
# ..        ...           ...             ...           ...
# 65    AL-PAYC      0.322420        0.165726  25772.862511
# 25    AER-RHI      0.432064        0.125614  13651.417840
# 64    AYR-IPG      0.194136        0.085882  10439.477197
# 41   ASGN-RHI      0.151774        0.063220  10109.468347
# 40   ELLI-IPG      0.122405        0.052347  16823.741195
# 60    AMN-IPG      0.120884        0.048094  18411.227083
# 36   ASGN-NSP      0.079748        0.039865  12293.055329
# 10     AER-AL      0.071710        0.038034   6673.045894
# 46  LXFT-TWTR      0.010400        0.026110  18779.886230
# 22   AER-LXFT      0.074210        0.003021  17205.570639
# 37   JNPR-NOW      0.065817       -0.004460  13571.272106
# 59  ECOM-SSTK     -0.125544       -0.010616  32743.069658
# 3     AER-FDS     -0.354582       -0.022771   9347.088726
# 29  ASGN-ELLI     -0.016221       -0.031831  27796.515524
# 23    AER-IPG     -1.174954       -0.038181   8582.623082
# 51    FDS-WIT     -2.211138       -0.062336   7499.291419
# 7      AL-FDS     -0.729153       -0.087712   8421.075749
# 27    AER-STM     -0.526001       -0.128977   8348.063940
# 38   HUBS-IPG     -0.949132       -0.129259  11474.880818
# 35     AL-WIT     -1.862374       -0.143497   9717.966088
# 57  MODN-PANW     -0.292922       -0.151942  19936.306209
# 48   AER-TWTR     -0.385784       -0.206371  24948.500325
# 16   ASGN-WIT     -1.948304       -0.212279   8570.110260
# 1     AER-MAN     -1.051246       -0.233734  10291.365371
# 43    AMN-AYR     -2.784880       -0.296338  10860.927012
# 33  HUBS-SQNS     -0.137801       -0.408978  36046.310103
# 28    STM-WIT     -1.686917       -0.465395  12768.476598
# 53  ELLI-MODN     -0.764014       -0.534139  19655.261054
# 44   GLOB-KAI     -0.578195       -0.586887  20022.129360
# 54    NSP-WIT     -1.330502       -0.619022  17946.319245
#
#     returns_std_thousands
# 62                 67.640
# 19                 60.032
# 12                 75.049
# 4                  30.169
# 55                 21.078
# 5                  27.160
# 63                 25.536
# 56                 22.144
# 47                 14.561
# 42                 24.615
# 2                  20.297
# 11                 16.930
# 15                 25.638
# 24                 17.899
# 31                 14.351
# 21                 16.261
# 0                  17.337
# 34                 21.695
# 13                 34.982
# 50                 17.543
# 58                 27.153
# 8                  18.825
# 17                 46.858
# 39                 20.083
# 52                 12.654
# 18                 11.466
# 6                  13.537
# 14                 17.935
# 61                 13.606
# 20                 20.084
# ..                    ...
# 65                 25.773
# 25                 13.651
# 64                 10.439
# 41                 10.109
# 40                 16.824
# 60                 18.411
# 36                 12.293
# 10                  6.673
# 46                 18.780
# 22                 17.206
# 37                 13.571
# 59                 32.743
# 3                   9.347
# 29                 27.797
# 23                  8.583
# 51                  7.499
# 7                   8.421
# 27                  8.348
# 38                 11.475
# 35                  9.718
# 57                 19.936
# 48                 24.949
# 16                  8.570
# 1                  10.291
# 43                 10.861
# 33                 36.046
# 28                 12.768
# 53                 19.655
# 44                 20.022
# 54                 17.946
#
# [66 rows x 5 columns]

# %%
borrow_cost =  pd.read_csv(filepath_or_buffer = "~/Desktop/borrow_cost.txt", sep = '|')
borrow_cost
# Out:
#                                                                                #BOF  \
# #SYM  CUR   NAME                         CON       ISIN         REBATERATE  FEERATE
# A     USD   AGILENT TECHNOLOGIES INC     1715006   XXXXXXXU1016 2.1400       0.2500
# AA    USD   ALCOA CORP                   251962528 XXXXXXX21065 2.0512       0.3388
# AAAU  USD   PERTH MINT PHYSICAL GOLD ETF 329705746 XXXXXXX61025 -9.9172     12.3072
# AABA  USD   ALTABA INC                   278946664 XXXXXXX61017 2.1400       0.2500
# AABB  USD   ASIA BROADBAND INC           75216559  XXXXXXXL1008 2.1400       0.2500
# AABVF USD   ABERDEEN INTERNATIONAL INC.  60152167  CA0030691012 -15.1820    17.5720
# AAC   USD   AAC HOLDINGS INC             169041192 XXXXXXX71083 1.2068       1.1832
# AACS  USD   AMERICAN COMMERCE SOLUTIONS  30207299  XXXXXXX91008 2.1400       0.2500
# AACTF USD   AURORA SOLAR TECHNOLOGIES IN 195675323 CA05207J1084 -33.3684    35.7584
# AADR  USD   ADVISORSHARES DORSEY WRIGHT  77459165  XXXXXXXY2063 -1.4551      3.8451
# AAGC  USD   ALL AMERICAN GOLD CORP       88362966  XXXXXXXV1026 2.0900       0.3000
# AAGH  USD   AMERICA GREAT HEALTH         280898497 XXXXXXXT1016 2.1400       0.2500
# AAGIY USD   AIA GROUP LTD-SP ADR         90162715  XXXXXXX72053 1.9645       0.4255
# AAIIQ USD   ALABAMA AIRCRAFT INDUSTRIES  48014358  XXXXXXXE1001 2.1400       0.2500
# AAL   USD   AMERICAN AIRLINES GROUP INC  139673266 XXXXXXXR1023 2.0890       0.3010
# AAMC  USD   ALTISOURCE ASSET MANAGEMENT  118834665 VI02153X1080 -4.6551      7.0451
# AAME  USD   ATLANTIC AMERICAN CORP       265585    XXXXXXX91008 -0.9279      3.3179
# AAMMF USD   ALMADEX MINERALS LTD-NEW     319496815 CA02028L1076 -1.8540      4.2440
# AAN   USD   AARON'S INC                  3630029   XXXXXXX53006 2.1400       0.2500
# AAOI  USD   APPLIED OPTOELECTRONICS INC  135423662 XXXXXXXU1025 0.8949       1.4951
# AAON  USD   AAON INC                     265595    XXXXXXX02069 2.1400       0.2500
# AAP   USD   ADVANCE AUTO PARTS INC       4027      XXXXXXXY1064 2.1400       0.2500
# AAPJ  USD   AAP INC                      95309032  XXXXXXXT1034 2.1400       0.2500
# AAPL  USD   APPLE INC                    265598    XXXXXXX31005 2.1400       0.2500
# AAPT  USD   ALL AMERICAN PET CO INC      44001811  XXXXXXXF1066 2.0900       0.3000
# AASL  USD   AMERICA'S SUPPLIERS INC      242059185 XXXXXXXJ2050 2.1400       0.2500
# AASP  USD   ALL-AMERICAN SPORTPARK INC   30207319  XXXXXXXP1057 2.0900       0.3000
# AAT   USD   AMERICAN ASSETS TRUST INC    82819360  XXXXXXX31047 2.1400       0.2500
# AATV  USD   ADAPTIVE AD SYSTEMS INC      160872878 XXXXXXXA1007 2.0900       0.3000
# ...                                                                             ...
# ZNCM  USD   ZUNICOM INC                  115353523 XXXXXXXX4016 2.1400       0.2500
# ZNGA  USD   ZYNGA INC - CL A             98760277  XXXXXXXT1088 2.1400       0.2500
# ZNH   USD   CHINA SOUTHERN AIR-SPONS ADR 6607693   XXXXXXX91091 -11.4757    13.8657
# ZNKKY USD   ZENKOKU HOSHO CO - UNSP ADR  275573525 XXXXXXX51045 NaN             NaN
# ZNNC  USD   ZANN CORP                    33480903  XXXXXXXU3005 2.1400       0.2500
# ZNNMF USD   EESTOR CORP                  189562378 CA28201L1013 -34.6674    37.0574
# ZOM   USD   ZOMEDICA PHARMACEUTICALS COR 291813470 CA98979F1071 -32.7762    35.1662
# ZONX  USD   ZONZIA MEDIA INC             186362780 XXXXXXXL1044 2.0900       0.3000
# ZPAS  USD   ZOOMPASS HOLDINGS INC        266114993 XXXXXXXT2069 2.0900       0.3000
# ZPTAF USD   SURGE ENERGY INC             184168320 CA86880Y1097 0.9701       1.4199
# ZRMG  USD   SHENZHEN-ZHONGRONG MORGAN IN 280261218 XXXXXXXL1017 2.1400       0.2500
# ZROZ  USD   PIMCO 25+ YR ZERO CPN US TIF 69839360  XXXXXXXR8824 -2.4262      4.8162
# ZS    USD   ZSCALER INC                  310621426 XXXXXXXG1022 1.9277       0.4623
# ZSAN  USD   ZOSANO PHARMA CORP           304597609 XXXXXXXH2022 -6.7853      9.1753
# ZSTN  USD   ZST DIGITAL NETWORKS INC     69838413  XXXXXXXT2087 1.3806       1.0094
# ZTCOY USD   ZTE CORP-UNSPON ADR          54740639  XXXXXXXQ1058 -7.6418     10.0318
# ZTO   USD   ZTO EXPRESS CAYMAN INC-ADR   253210632 XXXXXXXA1051 1.9664       0.4236
# ZTR   USD   VIRTUS GLOBAL DVD &amp; INC  249089410 XXXXXXXW1071 -21.0275    23.4175
# ZTS   USD   ZOETIS INC                   121665622 XXXXXXXV1035 2.1400       0.2500
# ZUMZ  USD   ZUMIEZ INC                   34466024  XXXXXXX71015 1.5131       0.8769
# ZUO   USD   ZUORA INC - CLASS A          313675821 XXXXXXXV1061 0.7478       1.6422
# ZURVY USD   ZURICH INSURANCE GROUP-ADR   105653547 XXXXXXX51049 -4.2589      6.6489
# ZVTK  USD   ZEVOTEK INC                  96765892  XXXXXXXB3042 2.1400       0.2500
# ZWBC  USD   GOLDKEY CORP                 178731140 XXXXXXXN1046 NaN             NaN
# ZXAIY USD   CHINA ZENIX AUTO INTERNA-ADR 87836947  XXXXXXXE1047 0.0712       2.3188
# ZYME  USD   ZYMEWORKS INC                274189981 CA98985W1023 -6.6917      9.0817
# ZYNE  USD   ZYNERBA PHARMACEUTICALS INC  202225021 XXXXXXXX1090 -2.8300      5.2200
# ZYXI  USD   ZYNEX INC                    52413740  XXXXXXXM1036 -8.1867     10.5767
# ZZZOF USD   ZINC ONE RESOURCES INC       274242368 CA98959W1041 -11.2719    13.6619
# #EOF  12683 NaN                          NaN       NaN          NaN             NaN
#
#                                                                            2019.01.16  \
# #SYM  CUR   NAME                         CON       ISIN         REBATERATE  AVAILABLE
# A     USD   AGILENT TECHNOLOGIES INC     1715006   XXXXXXXU1016 2.1400      >10000000
# AA    USD   ALCOA CORP                   251962528 XXXXXXX21065 2.0512        6300000
# AAAU  USD   PERTH MINT PHYSICAL GOLD ETF 329705746 XXXXXXX61025 -9.9172          2000
# AABA  USD   ALTABA INC                   278946664 XXXXXXX61017 2.1400      >10000000
# AABB  USD   ASIA BROADBAND INC           75216559  XXXXXXXL1008 2.1400         100000
# AABVF USD   ABERDEEN INTERNATIONAL INC.  60152167  CA0030691012 -15.1820         2000
# AAC   USD   AAC HOLDINGS INC             169041192 XXXXXXX71083 1.2068         100000
# AACS  USD   AMERICAN COMMERCE SOLUTIONS  30207299  XXXXXXX91008 2.1400        1300000
# AACTF USD   AURORA SOLAR TECHNOLOGIES IN 195675323 CA05207J1084 -33.3684         5000
# AADR  USD   ADVISORSHARES DORSEY WRIGHT  77459165  XXXXXXXY2063 -1.4551         10000
# AAGC  USD   ALL AMERICAN GOLD CORP       88362966  XXXXXXXV1026 2.0900         250000
# AAGH  USD   AMERICA GREAT HEALTH         280898497 XXXXXXXT1016 2.1400           8000
# AAGIY USD   AIA GROUP LTD-SP ADR         90162715  XXXXXXX72053 1.9645         300000
# AAIIQ USD   ALABAMA AIRCRAFT INDUSTRIES  48014358  XXXXXXXE1001 2.1400          15000
# AAL   USD   AMERICAN AIRLINES GROUP INC  139673266 XXXXXXXR1023 2.0890        9100000
# AAMC  USD   ALTISOURCE ASSET MANAGEMENT  118834665 VI02153X1080 -4.6551         10000
# AAME  USD   ATLANTIC AMERICAN CORP       265585    XXXXXXX91008 -0.9279        300000
# AAMMF USD   ALMADEX MINERALS LTD-NEW     319496815 CA02028L1076 -1.8540        150000
# AAN   USD   AARON'S INC                  3630029   XXXXXXX53006 2.1400        7400000
# AAOI  USD   APPLIED OPTOELECTRONICS INC  135423662 XXXXXXXU1025 0.8949         300000
# AAON  USD   AAON INC                     265595    XXXXXXX02069 2.1400         950000
# AAP   USD   ADVANCE AUTO PARTS INC       4027      XXXXXXXY1064 2.1400        3500000
# AAPJ  USD   AAP INC                      95309032  XXXXXXXT1034 2.1400          10000
# AAPL  USD   APPLE INC                    265598    XXXXXXX31005 2.1400      >10000000
# AAPT  USD   ALL AMERICAN PET CO INC      44001811  XXXXXXXF1066 2.0900      >10000000
# AASL  USD   AMERICA'S SUPPLIERS INC      242059185 XXXXXXXJ2050 2.1400            900
# AASP  USD   ALL-AMERICAN SPORTPARK INC   30207319  XXXXXXXP1057 2.0900           2000
# AAT   USD   AMERICAN ASSETS TRUST INC    82819360  XXXXXXX31047 2.1400        1400000
# AATV  USD   ADAPTIVE AD SYSTEMS INC      160872878 XXXXXXXA1007 2.0900            900
# ...                                                                               ...
# ZNCM  USD   ZUNICOM INC                  115353523 XXXXXXXX4016 2.1400           2000
# ZNGA  USD   ZYNGA INC - CL A             98760277  XXXXXXXT1088 2.1400      >10000000
# ZNH   USD   CHINA SOUTHERN AIR-SPONS ADR 6607693   XXXXXXX91091 -11.4757        20000
# ZNKKY USD   ZENKOKU HOSHO CO - UNSP ADR  275573525 XXXXXXX51045 NaN              1000
# ZNNC  USD   ZANN CORP                    33480903  XXXXXXXU3005 2.1400         500000
# ZNNMF USD   EESTOR CORP                  189562378 CA28201L1013 -34.6674        25000
# ZOM   USD   ZOMEDICA PHARMACEUTICALS COR 291813470 CA98979F1071 -32.7762        65000
# ZONX  USD   ZONZIA MEDIA INC             186362780 XXXXXXXL1044 2.0900          70000
# ZPAS  USD   ZOOMPASS HOLDINGS INC        266114993 XXXXXXXT2069 2.0900          75000
# ZPTAF USD   SURGE ENERGY INC             184168320 CA86880Y1097 0.9701         500000
# ZRMG  USD   SHENZHEN-ZHONGRONG MORGAN IN 280261218 XXXXXXXL1017 2.1400            200
# ZROZ  USD   PIMCO 25+ YR ZERO CPN US TIF 69839360  XXXXXXXR8824 -2.4262          8000
# ZS    USD   ZSCALER INC                  310621426 XXXXXXXG1022 1.9277         300000
# ZSAN  USD   ZOSANO PHARMA CORP           304597609 XXXXXXXH2022 -6.7853        300000
# ZSTN  USD   ZST DIGITAL NETWORKS INC     69838413  XXXXXXXT2087 1.3806         100000
# ZTCOY USD   ZTE CORP-UNSPON ADR          54740639  XXXXXXXQ1058 -7.6418         10000
# ZTO   USD   ZTO EXPRESS CAYMAN INC-ADR   253210632 XXXXXXXA1051 1.9664        4600000
# ZTR   USD   VIRTUS GLOBAL DVD &amp; INC  249089410 XXXXXXXW1071 -21.0275       200000
# ZTS   USD   ZOETIS INC                   121665622 XXXXXXXV1035 2.1400      >10000000
# ZUMZ  USD   ZUMIEZ INC                   34466024  XXXXXXX71015 1.5131        1800000
# ZUO   USD   ZUORA INC - CLASS A          313675821 XXXXXXXV1061 0.7478        1500000
# ZURVY USD   ZURICH INSURANCE GROUP-ADR   105653547 XXXXXXX51049 -4.2589         25000
# ZVTK  USD   ZEVOTEK INC                  96765892  XXXXXXXB3042 2.1400           9000
# ZWBC  USD   GOLDKEY CORP                 178731140 XXXXXXXN1046 NaN              5000
# ZXAIY USD   CHINA ZENIX AUTO INTERNA-ADR 87836947  XXXXXXXE1047 0.0712         350000
# ZYME  USD   ZYMEWORKS INC                274189981 CA98985W1023 -6.6917         25000
# ZYNE  USD   ZYNERBA PHARMACEUTICALS INC  202225021 XXXXXXXX1090 -2.8300         70000
# ZYXI  USD   ZYNEX INC                    52413740  XXXXXXXM1036 -8.1867         35000
# ZZZOF USD   ZINC ONE RESOURCES INC       274242368 CA98959W1041 -11.2719       100000
# #EOF  12683 NaN                          NaN       NaN          NaN               NaN
#
#                                                                             05:30:03
# #SYM  CUR   NAME                         CON       ISIN         REBATERATE       NaN
# A     USD   AGILENT TECHNOLOGIES INC     1715006   XXXXXXXU1016 2.1400           NaN
# AA    USD   ALCOA CORP                   251962528 XXXXXXX21065 2.0512           NaN
# AAAU  USD   PERTH MINT PHYSICAL GOLD ETF 329705746 XXXXXXX61025 -9.9172          NaN
# AABA  USD   ALTABA INC                   278946664 XXXXXXX61017 2.1400           NaN
# AABB  USD   ASIA BROADBAND INC           75216559  XXXXXXXL1008 2.1400           NaN
# AABVF USD   ABERDEEN INTERNATIONAL INC.  60152167  CA0030691012 -15.1820         NaN
# AAC   USD   AAC HOLDINGS INC             169041192 XXXXXXX71083 1.2068           NaN
# AACS  USD   AMERICAN COMMERCE SOLUTIONS  30207299  XXXXXXX91008 2.1400           NaN
# AACTF USD   AURORA SOLAR TECHNOLOGIES IN 195675323 CA05207J1084 -33.3684         NaN
# AADR  USD   ADVISORSHARES DORSEY WRIGHT  77459165  XXXXXXXY2063 -1.4551          NaN
# AAGC  USD   ALL AMERICAN GOLD CORP       88362966  XXXXXXXV1026 2.0900           NaN
# AAGH  USD   AMERICA GREAT HEALTH         280898497 XXXXXXXT1016 2.1400           NaN
# AAGIY USD   AIA GROUP LTD-SP ADR         90162715  XXXXXXX72053 1.9645           NaN
# AAIIQ USD   ALABAMA AIRCRAFT INDUSTRIES  48014358  XXXXXXXE1001 2.1400           NaN
# AAL   USD   AMERICAN AIRLINES GROUP INC  139673266 XXXXXXXR1023 2.0890           NaN
# AAMC  USD   ALTISOURCE ASSET MANAGEMENT  118834665 VI02153X1080 -4.6551          NaN
# AAME  USD   ATLANTIC AMERICAN CORP       265585    XXXXXXX91008 -0.9279          NaN
# AAMMF USD   ALMADEX MINERALS LTD-NEW     319496815 CA02028L1076 -1.8540          NaN
# AAN   USD   AARON'S INC                  3630029   XXXXXXX53006 2.1400           NaN
# AAOI  USD   APPLIED OPTOELECTRONICS INC  135423662 XXXXXXXU1025 0.8949           NaN
# AAON  USD   AAON INC                     265595    XXXXXXX02069 2.1400           NaN
# AAP   USD   ADVANCE AUTO PARTS INC       4027      XXXXXXXY1064 2.1400           NaN
# AAPJ  USD   AAP INC                      95309032  XXXXXXXT1034 2.1400           NaN
# AAPL  USD   APPLE INC                    265598    XXXXXXX31005 2.1400           NaN
# AAPT  USD   ALL AMERICAN PET CO INC      44001811  XXXXXXXF1066 2.0900           NaN
# AASL  USD   AMERICA'S SUPPLIERS INC      242059185 XXXXXXXJ2050 2.1400           NaN
# AASP  USD   ALL-AMERICAN SPORTPARK INC   30207319  XXXXXXXP1057 2.0900           NaN
# AAT   USD   AMERICAN ASSETS TRUST INC    82819360  XXXXXXX31047 2.1400           NaN
# AATV  USD   ADAPTIVE AD SYSTEMS INC      160872878 XXXXXXXA1007 2.0900           NaN
# ...                                                                              ...
# ZNCM  USD   ZUNICOM INC                  115353523 XXXXXXXX4016 2.1400           NaN
# ZNGA  USD   ZYNGA INC - CL A             98760277  XXXXXXXT1088 2.1400           NaN
# ZNH   USD   CHINA SOUTHERN AIR-SPONS ADR 6607693   XXXXXXX91091 -11.4757         NaN
# ZNKKY USD   ZENKOKU HOSHO CO - UNSP ADR  275573525 XXXXXXX51045 NaN              NaN
# ZNNC  USD   ZANN CORP                    33480903  XXXXXXXU3005 2.1400           NaN
# ZNNMF USD   EESTOR CORP                  189562378 CA28201L1013 -34.6674         NaN
# ZOM   USD   ZOMEDICA PHARMACEUTICALS COR 291813470 CA98979F1071 -32.7762         NaN
# ZONX  USD   ZONZIA MEDIA INC             186362780 XXXXXXXL1044 2.0900           NaN
# ZPAS  USD   ZOOMPASS HOLDINGS INC        266114993 XXXXXXXT2069 2.0900           NaN
# ZPTAF USD   SURGE ENERGY INC             184168320 CA86880Y1097 0.9701           NaN
# ZRMG  USD   SHENZHEN-ZHONGRONG MORGAN IN 280261218 XXXXXXXL1017 2.1400           NaN
# ZROZ  USD   PIMCO 25+ YR ZERO CPN US TIF 69839360  XXXXXXXR8824 -2.4262          NaN
# ZS    USD   ZSCALER INC                  310621426 XXXXXXXG1022 1.9277           NaN
# ZSAN  USD   ZOSANO PHARMA CORP           304597609 XXXXXXXH2022 -6.7853          NaN
# ZSTN  USD   ZST DIGITAL NETWORKS INC     69838413  XXXXXXXT2087 1.3806           NaN
# ZTCOY USD   ZTE CORP-UNSPON ADR          54740639  XXXXXXXQ1058 -7.6418          NaN
# ZTO   USD   ZTO EXPRESS CAYMAN INC-ADR   253210632 XXXXXXXA1051 1.9664           NaN
# ZTR   USD   VIRTUS GLOBAL DVD &amp; INC  249089410 XXXXXXXW1071 -21.0275         NaN
# ZTS   USD   ZOETIS INC                   121665622 XXXXXXXV1035 2.1400           NaN
# ZUMZ  USD   ZUMIEZ INC                   34466024  XXXXXXX71015 1.5131           NaN
# ZUO   USD   ZUORA INC - CLASS A          313675821 XXXXXXXV1061 0.7478           NaN
# ZURVY USD   ZURICH INSURANCE GROUP-ADR   105653547 XXXXXXX51049 -4.2589          NaN
# ZVTK  USD   ZEVOTEK INC                  96765892  XXXXXXXB3042 2.1400           NaN
# ZWBC  USD   GOLDKEY CORP                 178731140 XXXXXXXN1046 NaN              NaN
# ZXAIY USD   CHINA ZENIX AUTO INTERNA-ADR 87836947  XXXXXXXE1047 0.0712           NaN
# ZYME  USD   ZYMEWORKS INC                274189981 CA98985W1023 -6.6917          NaN
# ZYNE  USD   ZYNERBA PHARMACEUTICALS INC  202225021 XXXXXXXX1090 -2.8300          NaN
# ZYXI  USD   ZYNEX INC                    52413740  XXXXXXXM1036 -8.1867          NaN
# ZZZOF USD   ZINC ONE RESOURCES INC       274242368 CA98959W1041 -11.2719         NaN
# #EOF  12683 NaN                          NaN       NaN          NaN              NaN
#
# [12685 rows x 3 columns]
