# %%
import sys
# !{sys.executable} -m pip install --user pykalman
# !{sys.executable} -m pip install --user statsmodels
# !{sys.executable} -m pip install --user arch
# Out:
# Requirement already satisfied: pykalman in /home/u24027/.local/lib/python3.6/site-packages
# You are using pip version 9.0.1, however version 19.0.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# Requirement already satisfied: statsmodels in /home/u24027/.local/lib/python3.6/site-packages
# Requirement already satisfied: patsy in /home/u24027/.local/lib/python3.6/site-packages (from statsmodels)
# Requirement already satisfied: pandas in /glob/intel-python/versions/2018u2/intelpython3/lib/python3.6/site-packages (from statsmodels)
# Requirement already satisfied: numpy>=1.4 in /glob/intel-python/versions/2018u2/intelpython3/lib/python3.6/site-packages (from patsy->statsmodels)
# Requirement already satisfied: six in /glob/intel-python/versions/2018u2/intelpython3/lib/python3.6/site-packages (from patsy->statsmodels)
# Requirement already satisfied: python-dateutil>=2 in /glob/intel-python/versions/2018u2/intelpython3/lib/python3.6/site-packages (from pandas->statsmodels)
# Requirement already satisfied: pytz>=2011k in /glob/intel-python/versions/2018u2/intelpython3/lib/python3.6/site-packages (from pandas->statsmodels)
# You are using pip version 9.0.1, however version 19.0.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# Collecting arch
#   Downloading https://files.pythonhosted.org/packages/67/cb/adc9607bc4871c231f4d5d6510a809f38b007da8fc5a46604f97a49ef741/arch-4.7.0-cp36-cp36m-manylinux1_x86_64.whl (561kB)
#     100% |████████████████████████████████| 563kB 253kB/s eta 0:00:01    41% |█████████████▍                  | 235kB 28.8MB/s eta 0:00:01
# Requirement already satisfied: numpy>=1.12 in /glob/intel-python/versions/2018u2/intelpython3/lib/python3.6/site-packages (from arch)
# Requirement already satisfied: pandas>=0.20 in /glob/intel-python/versions/2018u2/intelpython3/lib/python3.6/site-packages (from arch)
# Requirement already satisfied: scipy>=0.19 in /glob/intel-python/versions/2018u2/intelpython3/lib/python3.6/site-packages (from arch)
# Requirement already satisfied: statsmodels>=0.8 in /home/u24027/.local/lib/python3.6/site-packages (from arch)
# Collecting cached-property>=1.5.1 (from arch)
#   Downloading https://files.pythonhosted.org/packages/3b/86/85c1be2e8db9e13ef9a350aecd6dea292bd612fa288c2f40d035bb750ded/cached_property-1.5.1-py2.py3-none-any.whl
# Requirement already satisfied: python-dateutil>=2 in /glob/intel-python/versions/2018u2/intelpython3/lib/python3.6/site-packages (from pandas>=0.20->arch)
# Requirement already satisfied: pytz>=2011k in /glob/intel-python/versions/2018u2/intelpython3/lib/python3.6/site-packages (from pandas>=0.20->arch)
# Requirement already satisfied: patsy in /home/u24027/.local/lib/python3.6/site-packages (from statsmodels>=0.8->arch)
# Requirement already satisfied: six>=1.5 in /glob/intel-python/versions/2018u2/intelpython3/lib/python3.6/site-packages (from python-dateutil>=2->pandas>=0.20->arch)
# Installing collected packages: cached-property, arch
# Successfully installed arch-4.7.0 cached-property-1.5.1
# You are using pip version 9.0.1, however version 19.0.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
import math
import pandas as pd
import numpy as np
from pykalman import KalmanFilter

import statsmodels.tsa.stattools as smts
import statsmodels.api as sm

from matplotlib import pyplot as plt

# %% [markdown]
# ### Kalman Filter

# %%
# read data
stk1 = pd.read_csv("../ib-data/nyse-daily-tech/DATA.csv")
stk2 = pd.read_csv("../ib-data/nyse-daily-tech/OOMA.csv")
N = min(len(stk1), len(stk2))

stk1 = stk1[-N:].reset_index(drop=True)
stk2 = stk2[-N:].reset_index(drop=True)

# ensure both arrays are of same length
stk1_array = np.log(stk1["close"][:, np.newaxis])
stk2_array = np.log(stk2["close"][:, np.newaxis])

# observation matrix
C = np.hstack((np.ones_like(stk2_array), stk2_array))
C = C.reshape(N, 1, 2)

# state transition matrix
T = np.array([[[1, 0], 
              [0, 1]]])
T = T.repeat(N - 1, axis = 0)

# %%
kf = KalmanFilter(em_vars=['transition_covariance', 
                           'observation_covariance', 
                           'initial_state_mean', 
                           'initial_state_covariance'], 
                  transition_matrices=T,
                  observation_matrices=C,
                  n_dim_state=2, 
                  n_dim_obs=1)

# %%
kf.em(X=stk1_array, n_iter=50)

# %%
math.sqrt(kf.observation_covariance)
# Out:
# 0.00670933475163254

# %%
filtered_state_means, filtered_state_covariances = kf.filter(X=stk1_array)

# %%
filtered_state_means.shape
# Out:
# (874, 2)

# %% [markdown]
# ### Calculate using both Rolling Least Squares and Kalman Filter

# %%
def compute_alpha_beta(Y, X):
    ln_Y = np.log(Y)
    ln_X = np.log(X)
    _X = sm.add_constant(ln_X)

    model = sm.OLS(ln_Y, _X)
    results = model.fit()
    beta, alpha = results.params
    return alpha, beta

def generate_pair_df(df1, df2, train_period=120, history_period=252):
    df1_history, df1_train = df1[:history_period], df1[history_period:history_period + train_period]
    df2_history, df2_train = df2[:history_period], df2[history_period:history_period + train_period]
    df1_test, df2_test = df1[history_period + train_period:], df2[history_period + train_period:]
    
    testing_period = len(df1_test)

    df_combined = pd.DataFrame()

    df_combined["close1"] = df1_test["close"].values
    df_combined["logClose1"] = np.log(df1_test["close"]).values
    df_combined["close2"] = df2_test["close"].values
    df_combined["logClose2"] = np.log(df2_test["close"]).values
    
    ##################################################################################################
    # compute alpha and beta using rolling OLS
    df_combined = df_combined.reset_index(drop=True)
    alpha_t, beta_t = [], []
    for i in range(testing_period):
        # i-th test day
        df1_window = df1[history_period + i : train_period + history_period + i]['close']
        df2_window = df2[history_period + i : train_period + history_period + i]['close']
        a, b = compute_alpha_beta(df1_window, df2_window)
        alpha_t.append(a)
        beta_t.append(b)
    df_combined["rolling_ols_alpha"] = pd.Series(alpha_t).values
    df_combined["rolling_ols_beta"] = pd.Series(beta_t).values
    df_combined["rolling_ols_spread"] = df_combined["logClose1"] - df_combined["logClose2"] * df_combined["rolling_ols_alpha"] - df_combined["rolling_ols_beta"]
    
    ##################################################################################################
    # compute alpha and beta using rolling kalman filter
    # 0. define matrices
    stk1_array = np.log(df1_history["close"][:, np.newaxis])
    stk2_array = np.log(df2_history["close"][:, np.newaxis])
    
    # observation matrix
    C = np.hstack((np.ones_like(stk2_array), stk2_array))
    C = C.reshape(history_period, 1, 2)
    
    # state transition matrix
    I = np.array([[[1, 0], 
                  [0, 1]]])
    T = I.repeat(history_period - 1, axis = 0)
    
    kf = KalmanFilter(em_vars=['transition_covariance', 
                           'observation_covariance', 
                           'initial_state_mean', 
                           'initial_state_covariance'], 
                      transition_matrices=T,
                      observation_matrices=C,
                      n_dim_state=2, 
                      n_dim_obs=1)
    
    # 1. EM training on history to estimate sigmas
    kf.em(X=stk1_array, n_iter=10)
    
    # 2. predict new hidden states (one by one) in testing period
    n_timesteps = len(df1)
    filtered_state_means = np.zeros((n_timesteps, 2))
    filtered_state_covariances = np.zeros((n_timesteps, 2, 2))
    filtered_state_means[0:history_period], filtered_state_covariances[0:history_period] = kf.filter(X=stk1_array)
        
    for t in range(history_period - 1, n_timesteps - 1):
        observation_t = np.array([math.log(df1['close'][t])])
        observation_matrix_t = np.array([1, math.log(df2['close'][t])]).reshape(1, 2)
        
        filtered_state_means[t + 1], filtered_state_covariances[t + 1] = (
            kf.filter_update(
                filtered_state_means[t],
                filtered_state_covariances[t],
                observation=observation_t,
                transition_matrix=I.reshape(2, 2),
                observation_matrix=observation_matrix_t
            )
        )
    
    df_combined["kalman_alpha"] = pd.Series(filtered_state_means[-testing_period: , 1]).values
    df_combined["kalman_beta"] = pd.Series(filtered_state_means[-testing_period: , 0]).values
    df_combined["kalman_spread"] = df_combined["logClose1"] - df_combined["logClose2"] * df_combined["kalman_alpha"] - df_combined["kalman_beta"]
    
    return df_combined

# %%
def compute_kalman_spread(df1, df2, history_period=252):
    df1_history, df1_test = df1[:history_period], df1[history_period:]
    df2_history, df2_test = df2[:history_period], df2[history_period:]

    df_combined = pd.DataFrame()
    df_combined["close1"] = df1_test["close"].values
    df_combined["logClose1"] = np.log(df1_test["close"]).values
    df_combined["close2"] = df2_test["close"].values
    df_combined["logClose2"] = np.log(df2_test["close"]).values
    
    ##################################################################################################
    # compute alpha and beta using rolling kalman filter
    # 0. define matrices
    stk1_array = np.log(df1_history["close"][:, np.newaxis])
    stk2_array = np.log(df2_history["close"][:, np.newaxis])
    
    # observation matrix
    C = np.hstack((np.ones_like(stk2_array), stk2_array))
    C = C.reshape(history_period, 1, 2)
    
    # state transition matrix
    I = np.array([[[1, 0], 
                  [0, 1]]])
    T = I.repeat(history_period - 1, axis = 0)
    
    kf = KalmanFilter(em_vars=['transition_covariance', 
                           'observation_covariance', 
                           'initial_state_mean', 
                           'initial_state_covariance'], 
                      transition_matrices=T,
                      observation_matrices=C,
                      n_dim_state=2, 
                      n_dim_obs=1)
    
    ##################################################################################################
    # 1. EM training on history to estimate sigmas
    kf.em(X=stk1_array, n_iter=10)
    observation_variance = kf.observation_covariance[0][0]
    
    ##################################################################################################
    # 2. predict new hidden states (one by one) in testing period
    n_timesteps = len(df1)
    filtered_state_means = np.zeros((n_timesteps, 2))
    filtered_state_covariances = np.zeros((n_timesteps, 2, 2))
    filtered_state_means[0:history_period], filtered_state_covariances[0:history_period] = kf.filter(X=stk1_array)
        
    for t in range(history_period - 1, n_timesteps - 1):
        observation_t = np.array([math.log(df1['close'][t])])
        observation_matrix_t = np.array([1, math.log(df2['close'][t])]).reshape(1, 2)
        
        filtered_state_means[t + 1], filtered_state_covariances[t + 1] = (
            kf.filter_update(
                filtered_state_means[t],
                filtered_state_covariances[t],
                observation=observation_t,
                transition_matrix=I.reshape(2, 2),
                observation_matrix=observation_matrix_t
            )
        )
        
    ##################################################################################################
    # 3. compute the new columns
    testing_period = len(df1_test)
    df_combined["kalman_alpha"] = pd.Series(filtered_state_means[-testing_period: , 1]).values
    df_combined["kalman_beta"] = pd.Series(filtered_state_means[-testing_period: , 0]).values
    df_combined["kalman_spread"] = df_combined["logClose1"] - df_combined["logClose2"] * df_combined["kalman_alpha"] - df_combined["kalman_beta"]
    df_combined["kalman_spread_normalized"] = df_combined["kalman_spread"] / math.sqrt(observation_variance)
    
    return df_combined

# %%
# read data
# DATA-OOMA
# AER-XRX
stk1 = pd.read_csv("../ib-data/nyse-daily-tech/AER.csv")
stk2 = pd.read_csv("../ib-data/nyse-daily-tech/XRX.csv")
N = min(len(stk1), len(stk2))

stk1 = stk1[-N:].reset_index(drop=True)
stk2 = stk2[-N:].reset_index(drop=True)

# %%
kalman_df = compute_kalman_spread(stk1, stk2)

# %%
rolling_df = generate_pair_df(stk1, stk2)
rolling_df.shape
# Out:
# (502, 10)

# %%
kalman_df["kalman_spread"].mean()
# Out:
# 0.000630568087502464

# %%
plt.plot(kalman_df["kalman_alpha"])
plt.show()

# %% [markdown]
# ### Compare

# %%
rolling_df
# Out:
#       close1  logClose1  close2  logClose2  rolling_ols_alpha  \
# 0     44.975   3.806107   9.325   2.232699          -1.063745
# 1     45.255   3.812313   9.475   2.248657          -1.079314
# 2     45.195   3.810986   9.125   2.211018          -1.087001
# 3     45.210   3.811318   9.350   2.235376          -1.077062
# 4     44.765   3.801427   9.225   2.221917          -1.079852
# 5     45.055   3.807884   9.075   2.205523          -1.077081
# 6     44.240   3.789629   8.975   2.194443          -1.070611
# 7     44.490   3.795264   8.975   2.194443          -1.058894
# 8     44.825   3.802766   8.975   2.194443          -1.047778
# 9     44.905   3.804549   9.075   2.205523          -1.027069
# 10    44.715   3.800309   9.075   2.205523          -1.012462
# 11    46.445   3.838269   9.125   2.211018          -0.994522
# 12    47.845   3.867967   9.475   2.248657          -0.970786
# 13    48.225   3.875878   9.625   2.264364          -0.947477
# 14    48.135   3.874010   9.775   2.279828          -0.911840
# 15    47.715   3.865246   9.775   2.279828          -0.861924
# 16    47.850   3.868071   9.625   2.264364          -0.827136
# 17    48.480   3.881151   9.525   2.253920          -0.802808
# 18    48.220   3.875774   9.825   2.284930          -0.778465
# 19    55.170   4.010419   9.975   2.300082          -0.734461
# 20    54.110   3.991019   9.775   2.279828          -0.604714
# 21    53.575   3.981083   9.825   2.284930          -0.524265
# 22    53.935   3.987780   9.875   2.290006          -0.438825
# 23    54.005   3.989077  10.025   2.305082          -0.351355
# 24    53.770   3.984716  10.175   2.319934          -0.250962
# 25    53.820   3.985645  10.175   2.319934          -0.140219
# 26    54.075   3.990372  10.125   2.315008          -0.031850
# 27    55.015   4.007606  10.175   2.319934           0.117018
# 28    54.055   3.990002  10.250   2.327278           0.259505
# 29    54.620   4.000400  10.075   2.310057           0.406902
# ..       ...        ...     ...        ...                ...
# 472  104.875   4.652769  13.470   2.600465           0.290328
# 473  107.575   4.678188  13.815   2.625755           0.286434
# 474  108.615   4.687810  13.690   2.616666           0.285199
# 475  112.485   4.722820  13.670   2.615204           0.284975
# 476  112.525   4.723175  13.585   2.608966           0.280544
# 477  118.790   4.777357  15.585   2.746309           0.264838
# 478  122.295   4.806436  15.195   2.720966           0.264763
# 479  124.645   4.825470  14.955   2.705046           0.262120
# 480  127.400   4.847332  15.635   2.749512           0.257451
# 481  123.685   4.817738  14.275   2.658510           0.264375
# 482  127.965   4.851757  14.220   2.654649           0.251669
# 483  123.410   4.815512  13.965   2.636554           0.233093
# 484  127.145   4.845328  14.125   2.647946           0.218359
# 485  127.405   4.847371  14.265   2.657809           0.194405
# 486  128.835   4.858533  14.275   2.658510           0.166763
# 487  130.805   4.873708  13.865   2.629368           0.120546
# 488  128.865   4.858765  13.560   2.607124           0.044594
# 489  120.090   4.788241  13.265   2.585129          -0.045666
# 490  121.545   4.800285  13.280   2.586259          -0.103888
# 491  121.935   4.803488  13.285   2.586636          -0.165597
# 492  119.275   4.781432  13.995   2.638700          -0.225671
# 493  112.155   4.719882  13.560   2.607124          -0.260647
# 494  110.200   4.702297  13.475   2.600836          -0.270069
# 495  118.865   4.777988  13.915   2.632967          -0.267149
# 496  119.915   4.786783  13.925   2.633686          -0.279856
# 497  118.245   4.772759  13.780   2.623218          -0.290423
# 498  119.975   4.787283  13.870   2.629728          -0.302052
# 499  118.640   4.776094  14.105   2.646529          -0.308655
# 500  115.715   4.751130  14.075   2.644400          -0.315215
# 501  124.800   4.826712  14.345   2.663401          -0.318884
#
#      rolling_ols_beta  rolling_ols_spread  kalman_alpha  kalman_beta  \
# 0            6.237186           -0.056057      0.189821     3.380792
# 1            6.270529           -0.031209      0.194162     3.372329
# 2            6.286762           -0.072398      0.204803     3.351206
# 3            6.263896           -0.044940      0.198349     3.371153
# 4            6.269206           -0.068438      0.188136     3.391331
# 5            6.261783           -0.078371      0.180078     3.402825
# 6            6.246589           -0.107565      0.181625     3.405748
# 7            6.219447           -0.100501      0.176139     3.406116
# 8            6.193616           -0.091560      0.180083     3.399537
# 9            6.146850           -0.077077      0.194092     3.375170
# 10           6.113563           -0.080246      0.197946     3.367716
# 11           6.073024           -0.035851      0.189807     3.382486
# 12           6.020152            0.030780      0.277799     3.216955
# 13           5.969201            0.052109      0.402948     2.957888
# 14           5.891424            0.061425      0.421249     2.921122
# 15           5.782239            0.048047      0.399367     2.964681
# 16           5.705949            0.035059      0.379583     3.001447
# 17           5.652507            0.038110      0.385897     2.993074
# 18           5.599146            0.055367      0.403158     2.969313
# 19           5.502643            0.197096      0.351616     3.074519
# 20           5.219123            0.150540      0.710186     2.358407
# 21           5.043025            0.135966      0.721541     2.343886
# 22           4.855951            0.136740      0.699065     2.385566
# 23           4.664342            0.134636      0.701933     2.380140
# 24           4.444027            0.122904      0.677906     2.427760
# 25           4.200499            0.110445      0.636731     2.509712
# 26           3.961886            0.102219      0.634380     2.514101
# 27           3.632609            0.103523      0.646269     2.493155
# 28           3.317282            0.068781      0.676531     2.435971
# 29           2.990494            0.069938      0.632258     2.521361
# ..                ...                 ...           ...          ...
# 472          3.872405            0.025376      0.397706     3.614634
# 473          3.883223            0.042860      0.402398     3.606099
# 474          3.886842            0.054696      0.430084     3.547983
# 475          3.887733            0.089820      0.446885     3.517579
# 476          3.900343            0.090903      0.493545     3.429860
# 477          3.943897            0.106134      0.500300     3.417558
# 478          3.945094            0.140931      0.464596     3.501923
# 479          3.953541            0.162882      0.505232     3.429793
# 480          3.967631            0.171838      0.534979     3.376894
# 481          3.950184            0.164712      0.534223     3.378501
# 482          3.986072            0.197592      0.539620     3.382177
# 483          4.038237            0.162713      0.582594     3.303113
# 484          4.079541            0.187583      0.558141     3.345314
# 485          4.146347            0.184332      0.589276     3.283711
# 486          4.223337            0.191855      0.585761     3.290668
# 487          4.351435            0.205313      0.599270     3.264783
# 488          4.561339            0.181164      0.628402     3.219459
# 489          4.810541            0.095753      0.629324     3.217978
# 490          4.971365            0.097601      0.576853     3.300718
# 491          5.141992            0.089835      0.587219     3.281079
# 492          5.307854            0.069056      0.591976     3.272033
# 493          5.404981           -0.005560      0.482602     3.510875
# 494          5.431514           -0.026812      0.439910     3.576031
# 495          5.424123            0.057262      0.418511     3.614952
# 496          5.459951            0.063884      0.527164     3.386476
# 497          5.489824            0.044778      0.543011     3.355965
# 498          5.522421            0.059176      0.534278     3.371690
# 499          5.541237            0.051722      0.548973     3.343009
# 500          5.559781            0.024905      0.518808     3.404169
# 501          5.570074            0.105954      0.487379     3.463729
#
#      kalman_spread
# 0         0.001502
# 1         0.003380
# 2         0.006957
# 3        -0.003219
# 4        -0.007928
# 5         0.007894
# 6        -0.014684
# 7         0.002621
# 8         0.008046
# 9         0.001306
# 10       -0.003982
# 11        0.036116
# 12        0.026338
# 13        0.005568
# 14       -0.007489
# 15       -0.009924
# 16        0.007111
# 17        0.018296
# 18       -0.014726
# 19        0.127156
# 20        0.013510
# 21       -0.011474
# 22        0.001349
# 23       -0.009077
# 24       -0.015741
# 25       -0.001241
# 26        0.007677
# 27        0.015150
# 28       -0.020444
# 29        0.018488
# ..             ...
# 472       0.003913
# 473       0.015491
# 474       0.014440
# 475       0.036545
# 476       0.005672
# 477      -0.014178
# 478       0.040364
# 479       0.029002
# 480      -0.000494
# 481       0.019000
# 482       0.037078
# 483      -0.023640
# 484       0.022087
# 485      -0.002524
# 486       0.010612
# 487       0.033224
# 488       0.000985
# 489      -0.056621
# 490       0.007675
# 491       0.003488
# 492      -0.052648
# 493      -0.049197
# 494      -0.017868
# 495       0.061110
# 496       0.011924
# 497      -0.007643
# 498       0.010588
# 499      -0.019788
# 500      -0.024974
# 501       0.064897
#
# [502 rows x 10 columns]

# %%
plt.plot(rolling_df["rolling_ols_spread"])
plt.show()

# %%
plt.plot(rolling_df["kalman_spread"])
plt.show()

# %%
from arch import arch_model

am = arch_model(rolling_df["kalman_spread"], p=76, q=49)
res = am.fit(update_freq=5)
fig = res.plot(annualize='D')
plt.show()
# Out:
# Iteration:      5,   Func. Count:    664,   Neg. LLF: -1196.578494523992
# Iteration:     10,   Func. Count: 1.33e+03,   Neg. LLF: -1197.5735428959042
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -1197.8567818374665
#             Iterations: 17
#             Function evaluations: 1733
#             Gradient evaluations: 13
# /home/u24027/.local/lib/python3.6/site-packages/arch/univariate/base.py:571: ConvergenceWarning:
# The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   ConvergenceWarning)

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# %%
plot_acf(rolling_df["kalman_spread"] ** 2, lags = 50)

# %%
plot_acf(rolling_df["kalman_spread"] ** 2, lags = range(50,100))

# %%
plot_acf(rolling_df["kalman_spread"] ** 2, lags = range(100,150))

# %%
plot_acf(rolling_df["kalman_spread"] ** 2, lags = range(150,200))

# %%
plt.plot(rolling_df["rolling_ols_alpha"], color='b')
plt.plot(rolling_df["kalman_alpha"], color='r')
plt.show()

# %%
plt.plot(rolling_df["rolling_ols_beta"], color='b')
plt.plot(rolling_df["kalman_beta"], color='r')
plt.show()

# %%
plt.plot(rolling_df['logClose1'], color = 'g')
plt.plot(rolling_df['logClose2'], color = 'b')
plt.show()
